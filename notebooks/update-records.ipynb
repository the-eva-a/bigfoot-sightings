# %%
# Import Dependencies
import requests
from bs4 import BeautifulSoup
import logging
import pandas as pd
import json
import matplotlib.pyplot as plt
import googlemaps
import pandas as pd
from dotenv import load_dotenv
import os

# %%
# Obtain environment variables
load_dotenv()
GOOGLE_MAPS_API_KEY = os.getenv('GOOGLE_MAPS_API_KEY')

# Initalize the Google Maps API Client (Replace SECRET with the actual key)
gmaps = googlemaps.Client(key=GOOGLE_MAPS_API_KEY)

# %%
# Load the data we have
bigfoot_data = pd.read_json('../data/raw_scraping_data.json')
bigfoot_data.head()
# Out:
#     Report Number Report Class  year  season      month   state  \
# 0  Report # 13038    (Class A)  2004  Winter   February  Alaska
# 1   Report # 8792    (Class B)  2003  Winter   December  Alaska
# 2   Report # 1255    (Class B)  1998    Fall  September  Alaska
# 3  Report # 11616    (Class B)  2004  Summer       July  Alaska
# 4    Report # 637    (Class A)  2000  Summer       June  Alaska
#
#                     county                                   location details  \
# 0         Anchorage County  Up near powerline clearings east of Potter Mar...
# 1         Anchorage County  Few houses on the way, a power relay station. ...
# 2            Bethel County  45 miles by air west of Lake Iliamna, Alaska i...
# 3       Bristol Bay County  Approximately 95 miles east of Egegik, Alaska....
# 4  Cordova-McCarthy County  On the main trail toward the glacier, before t...
#
#            nearest town               nearest road  \
# 0  Anchorage / Hillside  No real roads in the area
# 1             Anchorage                    Dowling
# 2                   NaN                        NaN
# 3                Egegik                        NaN
# 4      Kennikot, Alaska                   not sure
#
#                                             observed  \
# 0  I and two of my friends were bored one night s...
# 1  Me and a couple of friends had been bored, whe...
# 2  My hunting buddy and I were sitting on a ridge...
# 3  To whom it may concern, I am a commercial fish...
# 4  My hiking partner and I arrived late to the Ke...
#
#                                         also noticed  \
# 0  Some tracks in the snow, and a clearing in the...
# 1  We smelled of colonge and after shave, and one...
# 2                                    nothing unusual
# 3  Just these foot prints and how obvious it was ...
# 4  I did hear what appeared to be grunting in the...
#
#                                      other witnesses  \
# 0  My two friends were snowmachining behind me bu...
# 1  4. Me, w-man, warren and sean. We were at my h...
# 2  Scouting for caribou with high quality binoculars
# 3  One other witness, and he was fishing prior to...
# 4  I was the only witness, there was one other in...
#
#                                        other stories  \
# 0  I have not heard of any other incidents in Anc...
# 1                                                 no
# 2                                                NaN
# 3  I've only heard of one other story, from an ol...
# 4                                               None
#
#                                  time and conditions  \
# 0  Middle of the night. The only light was the he...
# 1  Started at 11, ended at about 3-3:30. Weather ...
# 2                                                NaN
# 3     Approximately 12:30 pm, partially coudy/sunny.
# 4  About 12:00 Midnight / full moon / clear / dim...
#
#                                          environment          date  \
# 0  In the middle of the woods, in a clearing cove...           NaN
# 1  A pine forest, with a bog or swamp on the righ...  Friday night
# 2  Call Iliamna Air taxi for lat & Long of Long L...             3
# 3  Lake front,creek spit, gravel and sand, alder ...            20
# 4  This sighting was located at approximately 1 t...            16
#
#   a & g references
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
# Configure logging
logging.basicConfig(
    filename='logs/bigfoot_updates.log',  # Log file name
    filemode='a',  # Append mode
    level=logging.DEBUG,  # Log everything from DEBUG and above
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# Bring over Functions 
def soupify_website(url):
    """
    Fetches the HTML content of a given URL and parses it into a BeautifulSoup object.

    Parameters:
        url (str): The URL of the webpage to be scraped.

    Returns:
        BeautifulSoup: A BeautifulSoup object representing the parsed HTML of the webpage.
    
    Raises:
        ValueError: If the HTTP response status is not 200(OK)
    """
    
    # test connection
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        return soup
    else:
        raise ValueError(f"Failed to fetch {url}: Status code {response.status_code}")

def get_report_links():
    """
    Extracts all report numbers from links from the Sighting Reports Recently Added page of the BFRO
    database. 

    Parameters:
        report_soup: A list of BeautifulSoup objects to search for links.

    Returns:
        list: A list of hyperlink strings (`href` values) extracted from the provided BeautifulSoup objects.
    
    Notes:
        - Only links with an `href` attribute will be included.
        - Duplicate links are not removed; the returned list may contain duplicates.
    """
    link_list = []
    report_soup = soupify_website('https://www.bfro.net/GDB/newadd.asp?Show=AB')
    links = report_soup.find_all('a')
    for link in links:
        if link.get('href') and 'show_report.asp?id=' in link.get('href') :
            url = link.get('href').split('show_report.asp?id=')[1]
            link_list.append(url)
    return link_list

def create_sighting_dictionary(url):
    """
    Extracts information from an individual report page and returns it as a dictionary.

    Parameters:
        url (str): The URL of the report page.

    Returns:
        dict: A dictionary with the extracted information, or None if the page cannot be parsed.
    """
    logging.info(f"Fetching report from: {url}")
    report = soupify_website(url)

    if not report:
        logging.error(f"Failed to parse report page: {url}")
        return None

    try:
        report_dict = {}

        # Extract 'Report Number'
        report_header = report.find('span', class_='reportheader')
        report_dict['Report Number'] = report_header.text.strip() if report_header else 'N/A'

        # Extract 'Report Classification'
        report_class = report.find('span', class_='reportclassification')
        report_dict['Report Class'] = report_class.text.strip() if report_class else 'N/A'

        # Extract additional fields
        fields = report.find_all('span', class_='field')
        for field in fields:
            # Get the full text of the parent element
            text = field.parent.text.strip()

            # Only process fields in the format "Header: Value"
            if ':' in text:
                # Split into field name and value
                field_name, value = text.split(':', 1)

                # Clean up field name and value
                field_name = field_name.strip().lower()
                value = value.strip()

                # Validate input (ensure no line breaks in the value)
                if len(value.split('\n')) == 1:
                    # Store the field and value in the dictionary
                    report_dict[field_name] = value

        return report_dict

    except Exception as e:
        logging.error(f"Error processing report {url}: {e}")
        return None
    
def geocode_with_fallback(row):
    try:
        # Try nearest_town, state
        location = gmaps.geocode(f"{row['nearest_town']}, {row['state']}")
        if location:
            return location[0]['geometry']['location']['lat'], location[0]['geometry']['location']['lng']

        # Fallback to county, state
        location = gmaps.geocode(f"{row['county']}, {row['state']}")
        if location:
            return location[0]['geometry']['location']['lat'], location[0]['geometry']['location']['lng']

        # If neither works, return None
        return None, None
    except Exception as e:
        print(f"Error geocoding {row['nearest_town']}, {row['state']} or {row['county']}, {row['state']}: {e}")
        return None, None
# Load raw data json 
bigfoot_data = pd.read_json('../data/raw_scraping_data.json')
new_sightings_url = 'https://www.bfro.net/GDB/newadd.asp?Show=AB'

# %%
latest_reports = get_report_links()
# Check our database for these reports
old_reports = bigfoot_data['Report Number'].str.split('Report # ').apply(lambda x: x[1] if len(x) > 1 else None).tolist()
# Ensure latest_reports are comparable
latest_reports = [str(x) for x in latest_reports]

new_reports = [x for x in latest_reports if x not in old_reports]

# %%
new_report_dicts = []
for report in new_reports:
    new_report_dicts.append(create_sighting_dictionary(f'https://www.bfro.net/GDB/show_report.asp?id={report}'))
new_report_df = pd.DataFrame(new_report_dicts)
new_report_df.head()
# Out:
#     Report Number Report Class  year  season     month        date  \
# 0  Report # 77879    (Class A)  2024    Fall  November           8
# 1  Report # 76281    (Class B)  2023  Summer      July          18
# 2  Report # 77818    (Class A)  2024    Fall   October        20th
# 3  Report # 77933    (Class A)  2024    Fall   October  10/26/2024
#
#            state            county  \
# 0       Virginia   Buchanan County
# 1  Massachusetts  Worcester County
# 2        Montana       Hill County
# 3      Tennessee     Monroe County
#
#                                     location details           nearest town  \
# 0  a well traveled road that is near the coal min...  no very far from town
# 1    Mt Wachusett is next to Leominster State Forest           Mt Wachusett
# 2  Was on the Rocky Boy Reservation on Sandy Cree...              Box Elder
# 3  Specific directions omitted to allow a follow-...         Tellico Plains
#
#                        nearest road  \
# 0                           page rd
# 1  On the ski slope of Mt Wachusett
# 2                    Sandy creek rd
# 3                               NaN
#
#                                             observed  \
# 0  I saw this at around 200-230 am I was running ...
# 1  First, I am a skeptic but I am willing to be o...
# 2  Sunday night my brother, his wife, my girlfrie...
# 3  My report for my visual sighting of a possible...
#
#                                         also noticed  \
# 0  As stated above there were 2 deer nearby that ...
# 1                                                NaN
# 2  We seen eyes in the bushes about ten minutes b...
# 3  Right after the sighting I remember hearing a ...
#
#                                    other witnesses  \
# 0                                     one (myself)
# 1                                               no
# 2  My brother. His wife, my girlfriend and myself.
# 3                               No other witnesses
#
#                                        other stories  \
# 0  I've heard stories but I have never spoken to ...
# 1  After I mentioned my experience, a woman told ...
# 2  Yes, there was an incident that happened back ...
# 3  This area has reportedly had a history of acti...
#
#                                  time and conditions  \
# 0  roughly 200 am very clear and bright night was...
# 1                                               dusk
# 2  It was about 11 or 11:30 pm maybe, but it was ...
# 3  2:15pm in the afternoon. It was sunny day with...
#
#                                          environment
# 0  Wooded saddle of the mountain. It was near a s...
# 1  slope of the ski slope. Mixed type of forest t...
# 2  Forest. Not too thick of vegetation tho. It wa...
# 3  Lush forest mixed with pines, vines and leafy ...

# %%
updated_raw = pd.concat([bigfoot_data, new_report_df], ignore_index=True)

# %%
updated_raw.to_json('raw_scraping_data.json', orient='records')

# %% [markdown]
# We have a dataframe of our new entries, now to clean them

# %%
new_report_df.columns = new_report_df.columns.str.replace(' ','_').str.lower()
new_report_df['report_number'] = new_report_df.loc[:, 'report_number'].apply(
  lambda x: pd.to_numeric(x.split('Report # ')[1]) if isinstance(x, str) and 'Report # ' in x else x)

new_report_df['report_class'] = new_report_df.loc[:, 'report_class'].apply(
    lambda x: x[6:-1].strip() if len(x) > 1 else x
)

# Standardize dates
new_report_df['date'] = pd.to_datetime(
    new_report_df['date'], errors='coerce', format='%Y-%m-%d'
)

# Clean up environment
new_report_df['environment'] = new_report_df['environment'].str.lower()

# Check for appropriate year
new_report_df = new_report_df[new_report_df['year'].str.match(r'^\d{4}$', na=False)]

# Handle missing values 
new_report_df.fillna({'nearest_town': 'Unknown', 'nearest_road': 'Unknown'}, inplace=True)

# %% [markdown]
# Finally, we add the geocoding

# %%
new_report_df[['latitude', 'longitude']] = new_report_df.apply(
    lambda row: pd.Series(geocode_with_fallback(row)), axis=1
)

# %%
bigfoot_df = pd.read_json('../data/bigfoot_coords_df.json')
bigfoot_df.head()
# Out:
#    report_number report_class  year  season      month   state  \
# 0          13038            A  2004  Winter   February  Alaska
# 1           8792            B  2003  Winter   December  Alaska
# 2           1255            B  1998    Fall  September  Alaska
# 3          11616            B  2004  Summer       July  Alaska
# 4            637            A  2000  Summer       June  Alaska
#
#                     county                                   location_details  \
# 0         Anchorage County  Up near powerline clearings east of Potter Mar...
# 1         Anchorage County  Few houses on the way, a power relay station. ...
# 2            Bethel County  45 miles by air west of Lake Iliamna, Alaska i...
# 3       Bristol Bay County  Approximately 95 miles east of Egegik, Alaska....
# 4  Cordova-McCarthy County  On the main trail toward the glacier, before t...
#
#            nearest_town               nearest_road  \
# 0  Anchorage / Hillside  No real roads in the area
# 1             Anchorage                    Dowling
# 2                  None                       None
# 3                Egegik                       None
# 4      Kennikot, Alaska                   not sure
#
#                                             observed  \
# 0  I and two of my friends were bored one night s...
# 1  Me and a couple of friends had been bored, whe...
# 2  My hunting buddy and I were sitting on a ridge...
# 3  To whom it may concern, I am a commercial fish...
# 4  My hiking partner and I arrived late to the Ke...
#
#                                         also_noticed  \
# 0  Some tracks in the snow, and a clearing in the...
# 1  We smelled of colonge and after shave, and one...
# 2                                    nothing unusual
# 3  Just these foot prints and how obvious it was ...
# 4  I did hear what appeared to be grunting in the...
#
#                                      other_witnesses  \
# 0  My two friends were snowmachining behind me bu...
# 1  4. Me, w-man, warren and sean. We were at my h...
# 2  Scouting for caribou with high quality binoculars
# 3  One other witness, and he was fishing prior to...
# 4  I was the only witness, there was one other in...
#
#                                        other_stories  \
# 0  I have not heard of any other incidents in Anc...
# 1                                                 no
# 2                                               None
# 3  I've only heard of one other story, from an ol...
# 4                                               None
#
#                                  time_and_conditions  \
# 0  Middle of the night. The only light was the he...
# 1  Started at 11, ended at about 3-3:30. Weather ...
# 2                                               None
# 3     Approximately 12:30 pm, partially coudy/sunny.
# 4  About 12:00 Midnight / full moon / clear / dim...
#
#                                          environment          date  \
# 0  In the middle of the woods, in a clearing cove...          None
# 1  A pine forest, with a bog or swamp on the righ...  Friday night
# 2  Call Iliamna Air taxi for lat & Long of Long L...             3
# 3  Lake front,creek spit, gravel and sand, alder ...            20
# 4  This sighting was located at approximately 1 t...            16
#
#   a_&_g_references   latitude   longitude
# 0             None  61.119996 -149.745430
# 1             None  61.217576 -149.899678
# 2             None  63.588753 -154.493062
# 3             None  58.213737 -157.374253
# 4             None  61.486389 -142.886389

# %%
coordinates_df = pd.concat([bigfoot_df, new_report_df],ignore_index=True)
coordinates_df.tail()
# Out:
#       report_number report_class  year  season     month          state  \
# 4778          77933            A  2024    Fall   October      Tennessee
# 4779          77879            A  2024    Fall  November       Virginia
# 4780          76281            B  2023  Summer      July  Massachusetts
# 4781          77818            A  2024    Fall   October        Montana
# 4782          77933            A  2024    Fall   October      Tennessee
#
#                 county                                   location_details  \
# 4778     Monroe County  Specific directions omitted to allow a follow-...
# 4779   Buchanan County  a well traveled road that is near the coal min...
# 4780  Worcester County    Mt Wachusett is next to Leominster State Forest
# 4781       Hill County  Was on the Rocky Boy Reservation on Sandy Cree...
# 4782     Monroe County  Specific directions omitted to allow a follow-...
#
#                nearest_town                      nearest_road  \
# 4778         Tellico Plains                           Unknown
# 4779  no very far from town                           page rd
# 4780           Mt Wachusett  On the ski slope of Mt Wachusett
# 4781              Box Elder                    Sandy creek rd
# 4782         Tellico Plains                           Unknown
#
#                                                observed  \
# 4778  My report for my visual sighting of a possible...
# 4779  I saw this at around 200-230 am I was running ...
# 4780  First, I am a skeptic but I am willing to be o...
# 4781  Sunday night my brother, his wife, my girlfrie...
# 4782  My report for my visual sighting of a possible...
#
#                                            also_noticed  \
# 4778  Right after the sighting I remember hearing a ...
# 4779  As stated above there were 2 deer nearby that ...
# 4780                                                NaN
# 4781  We seen eyes in the bushes about ten minutes b...
# 4782  Right after the sighting I remember hearing a ...
#
#                                       other_witnesses  \
# 4778                               No other witnesses
# 4779                                     one (myself)
# 4780                                               no
# 4781  My brother. His wife, my girlfriend and myself.
# 4782                               No other witnesses
#
#                                           other_stories  \
# 4778  This area has reportedly had a history of acti...
# 4779  I've heard stories but I have never spoken to ...
# 4780  After I mentioned my experience, a woman told ...
# 4781  Yes, there was an incident that happened back ...
# 4782  This area has reportedly had a history of acti...
#
#                                     time_and_conditions  \
# 4778  2:15pm in the afternoon. It was sunny day with...
# 4779  roughly 200 am very clear and bright night was...
# 4780                                               dusk
# 4781  It was about 11 or 11:30 pm maybe, but it was ...
# 4782  2:15pm in the afternoon. It was sunny day with...
#
#                                             environment  date  \
# 4778  lush forest mixed with pines, vines and leafy ...  None
# 4779  wooded saddle of the mountain. it was near a s...   NaN
# 4780  slope of the ski slope. mixed type of forest t...   NaN
# 4781  forest. not too thick of vegetation tho. it wa...   NaN
# 4782  lush forest mixed with pines, vines and leafy ...   NaN
#
#      a_&_g_references   latitude   longitude
# 4778             None  35.362855  -84.294087
# 4779              NaN  37.431573  -78.656894
# 4780              NaN  42.489172  -71.887042
# 4781              NaN  48.317208 -110.013263
# 4782              NaN  35.362855  -84.294087

# %%
coordinates_df.to_json('../data/bigfoot_coords_df.json', orient='records')

# %%
final_cols = ['report_number', 'report_class', 'state', 'county', 'latitude',
       'nearest_town', 'longitude', 'season', 'month', 'observed', 'year']

coordinates_df = coordinates_df[final_cols]

coordinates_df.to_json('../data/bigfoot_coordinates_clean_cols.json', orient='records')
